# %% [markdown]
# # 520天猫数据分析

# %% [markdown]
# ## 数据探索和数据清洗

# %% [markdown]
# 1. 去除重复值
# 2. 从goods_name中提取具体的商品名称
# 3. 将购买人数转换为数值型数据
# 4. 增加收入列，价格*购买人数=收入
# 5. 增加商品价格分箱数据

# %%
import numpy as np 
import pandas as pd 
import time 
import re 
import jieba
import jieba.analyse
from collections import Counter

from pyecharts.charts import Bar, Map, Pie, TreeMap, WordCloud, Page
from pyecharts import options as opts 
from pyecharts.globals import SymbolType

# %%
# 读入数据
df_all = pd.read_excel('../data/520礼物天猫数据.xlsx') 
df = df_all.copy()
df.head()
# Out:
#                              goods_name         shop_name  price purchase_num  \
# 0                  永生花礼盒告白玫瑰兔 送女朋友爱人生日礼      joyflower旗舰店  359.0    ['38人付款']
# 1  THEBEAST/野兽派音乐盒水晶球玫瑰永生花 结婚生日520礼物送女友  thebeast野兽派官方旗舰店  520.0  ['1175人付款']
# 2       进口永生花玻璃罩礼盒真花小王子玫瑰花情人节520送女友生日礼物             芊云旗舰店  179.0  ['1997人付款']
# 3  THE BEAST/野兽派永生花告白兔大声说爱你新婚生日520礼物送女友  thebeast野兽派官方旗舰店  630.0  ['1196人付款']
# 4     JANE永生花玫瑰花熊音乐旋转告白小熊礼520情人节礼物生日送女友    janeflowers旗舰店  258.0  ['2805人付款']
#
#   location
# 0       北京
# 1       上海
# 2    云南 昆明
# 3       上海
# 4    江苏 苏州

# %%
df[df.goods_name.str.contains('施华洛')]
# Out:
#                                          goods_name       shop_name   price  \
# 801               520生日礼物送女友纯银手链女手镯首饰ins小众采用施华洛世奇元素        glten旗舰店   253.0
# 805               四叶草手链女纯银ins小众设计施华洛世奇锆手饰手镯520礼物送女友         vigg旗舰店   183.0
# 812              施华洛世奇DAZZLING SWAN浪漫天鹅魅力百搭女手链520礼物      施华洛世奇官方旗舰店  1190.0
# 816               纯银手链女ins小众设计手饰手镯520礼物送女友采用施华洛世奇元素        glten旗舰店   353.0
# 821           【新品】施华洛世奇DAZZLING SWAN蓝调天鹅手链全新配色520礼物      施华洛世奇官方旗舰店  1190.0
# 849            【新品】施华洛世奇 LIFELONG HRT 挚爱璀璨 女手镯520礼物      施华洛世奇官方旗舰店  1290.0
# 850                施华洛世奇 FURTHER 环环相扣 现代风格 女手链520礼物      施华洛世奇官方旗舰店  1490.0
# 855               【直营】告白日施华洛世奇SWAN新款首饰镀玫瑰金天鹅手链520礼物        天猫国际时尚直营   569.0
# 863                 星座手链女采用施华洛世奇元素水晶手饰品小众设计520礼物送女友        静风格官方旗舰店   149.0
# 890              JG镶施华洛世奇闺蜜手链女ins小众设计潮纯银学生简约清新520礼物   johnsongem旗舰店    95.0
# 894                 小蛮腰手链女纯银手镯手饰学生520礼物送女友采用施华洛世奇元素        glten旗舰店   263.0
# 905               施华洛世奇ELDERFLOWER手链女士玫瑰金花朵手镯 520礼物      施华洛世奇官方旗舰店  1290.0
# 906            施华洛世奇渐变色天鹅 ICONIC SWAN 优雅时尚 女手镯520礼物      施华洛世奇官方旗舰店  1790.0
# 932                 四叶草手链女纯银玫瑰金手镯镶施华洛世奇元素520生日礼物送女友      莉迪卡娜蓓利思专卖店   188.0
# 961                  施华洛世奇 SWAN天鹅手镯 个性混搭 可调女手链520礼物      施华洛世奇官方旗舰店  1490.0
# 962               施华洛世奇 LOLLYPOP 黑白拼色简约百搭可调女手链520礼物      施华洛世奇官方旗舰店   645.0
# 1020              施华洛世奇 LOLLYPOP 黑白拼色简约百搭可调女手链520礼物      施华洛世奇官方旗舰店   645.0
# 1021                  施华洛世奇 LITTLE 萌趣小猪 浪漫女手链 520礼物      施华洛世奇官方旗舰店  1290.0
# 1076                  施华洛世奇 LITTLE 萌趣小猪 浪漫女手链 520礼物      施华洛世奇官方旗舰店  1290.0
# 1077        【新品】施华洛世奇 CHINESE ZODIAC 如意鼠造型 女手链520礼物      施华洛世奇官方旗舰店  1190.0
# 1102              纯银手链女生手镯镶施华洛世奇锆小众ins设计520礼物情人节送女友           宝恋旗舰店   189.0
# 1132             【新品】施华洛世奇 LITTLE 萌趣老鼠 清新色调 手链520礼物      施华洛世奇官方旗舰店  1290.0
# 1133      【新品】施华洛世奇 SWAROVSKI  INFINITY 情侣款 手链520礼物      施华洛世奇官方旗舰店   899.0
# 1188                施华洛世奇 MY HERO趣致玩味觔斗云芭蕉扇女手链520礼物      施华洛世奇官方旗舰店  1490.0
# 1189  施华洛世奇SWAROVSKI POWER COLLECTION 叠搭设计 女手链520礼物      施华洛世奇官方旗舰店   699.0
# 1247                施华洛世奇 MY HERO趣致玩味觔斗云芭蕉扇女手链520礼物      施华洛世奇官方旗舰店  1490.0
# 1248  施华洛世奇SWAROVSKI POWER COLLECTION 叠搭设计 女手链520礼物      施华洛世奇官方旗舰店   699.0
# 1259           IVLISA轻奢品牌纯银手链女ins小众设计冷淡风镶施华洛世奇520礼物       ivlisa旗舰店  1190.0
# 1290                  施华洛世奇 翻转魅力人手造型神秘色彩 女手链饰品520礼物      施华洛世奇官方旗舰店   645.0
# 1291      【新品】施华洛世奇 SWAROVSKI  INFINITY 情侣款 手链520礼物      施华洛世奇官方旗舰店   899.0
# ...                                             ...             ...     ...
# 3957             alainn春夏韩国进口东大门代购送礼银施华洛世奇珍珠耳环520礼物        天猫国际时尚直营   118.0
# 3960                轻奢手链女纯银镶施华洛世奇锆定制刻字手饰520情人节礼物送女友        国际高端奢侈品牌  1314.0
# 3971               18K白金一鹿有你手链女520手饰情人节礼物送女友镶施华洛世奇锆          卡蒂罗旗舰店   938.0
# 3975                轻奢手链女纯银镶施华洛世奇锆定制刻字手饰520情人节礼物送女友        国际高端奢侈品牌  1314.0
# 3981                施华洛世奇LATISHA典雅气质四叶草小花耳环女耳饰520礼物      施华洛世奇官方旗舰店   999.0
# 3982               施华洛世奇 ANGELIC透明圆形镀白金色单颗穿孔耳钉520礼物      施华洛世奇官方旗舰店   899.0
# 3989             alainn春夏韩国进口东大门代购送礼银施华洛世奇珍珠耳环520礼物        天猫国际时尚直营   118.0
# 4036        施华洛世奇耀动的心 SPARKLING DANCE 耀动星光 女戒指520礼物      施华洛世奇官方旗舰店   645.0
# 4037               施华洛世奇KRIS BEAR十二星座狮子座可爱小熊摆件520礼物      施华洛世奇官方旗舰店   499.0
# 4053              520海绵宝宝手链女纯银ins小众设计闺蜜镶施华洛世奇锆送女友礼物         vana旗舰店   348.0
# 4087             施华洛世奇 CRYSTALLINE 现代瑰丽精致优雅 手表520礼物      施华洛世奇官方旗舰店  3490.0
# 4088                施华洛世奇OXYGEN细致闪耀跃动晶彩华丽悦目女项链520礼物      施华洛世奇官方旗舰店  1290.0
# 4116               项链女18k金锁骨链白金吊坠镶施华洛世奇锆520情人节礼物送女友  sechilouis奢驰路易  1314.0
# 4121              vana纯银手镯女镶施华洛世奇锆小众设计学生日礼物送女友520手链         vana旗舰店   291.0
# 4129              999纯银项链女吊坠锁骨链生日520情人节礼物送女友镶施华洛世奇锆          银千惠旗舰店   139.0
# 4140                 施华洛世奇 ONE 俏皮爱心 浪漫爱意 女项链饰品520礼物      施华洛世奇官方旗舰店  1290.0
# 4141             施华洛世奇 CRYSTALLINE 现代瑰丽精致优雅 手表520礼物      施华洛世奇官方旗舰店  3490.0
# 4148                银手链女红绳本命年鼠年手绳520情人节礼物送女友镶施华洛世奇锆          银千惠旗舰店   159.0
# 4152              小蛮腰手镯女999纯银精致轻奢手饰品520礼物送女友镶施华洛世奇锆          卡蒂罗旗舰店   328.0
# 4195          【新品】施华洛世奇 BEE A QUEEN瑰丽皇冠华丽耀眼女手镯520礼物      施华洛世奇官方旗舰店  1690.0
# 4196           【新品】施华洛世奇TROPICAL 灵动鹦鹉趣致魅力女项链饰品520礼物      施华洛世奇官方旗舰店  1790.0
# 4248          【新品】施华洛世奇 Line Friends 瑜伽可妮兔 女耳钉520礼物      施华洛世奇官方旗舰店   999.0
# 4249            施华洛世奇CRYSTAL FROST雅致光彩活力气息 女手表520礼物      施华洛世奇官方旗舰店  2303.0
# 4262                卡蒂罗六芒星项链女锁骨链纯银520生日礼物女朋友镶施华洛世奇锆          卡蒂罗旗舰店   298.0
# 4299                施华洛世奇OLIVE 清新色调精致简约创意巧思女项链520礼物      施华洛世奇官方旗舰店   495.0
# 4300          【新品】施华洛世奇 Line Friends 瑜伽可妮兔 女耳钉520礼物      施华洛世奇官方旗舰店   999.0
# 4326                本命年520礼物送女友项链十二生肖鼠年纯银锁骨链施华洛世奇吊坠         t400旗舰店   159.0
# 4347               18K金对戒情侣戒指男女结婚一对个性520情人节礼物施华洛世奇锆           铂宫旗舰店   799.0
# 4354           【新品】施华洛世奇 LIFELONG HRT 扭结爱心 女手镯520礼物      施华洛世奇官方旗舰店  1490.0
# 4355      施华洛世奇 SWAROVSKI SYMBOL 神秘月亮 时尚魅力 女耳环520礼物      施华洛世奇官方旗舰店  1690.0
#
#      purchase_num location
# 801   ['1865人付款']    江苏 南京
# 805   ['2614人付款']    广东 深圳
# 812    ['204人付款']    浙江 嘉兴
# 816    ['188人付款']    江苏 南京
# 821    ['145人付款']    浙江 嘉兴
# 849    ['146人付款']    浙江 嘉兴
# 850     ['84人付款']    浙江 嘉兴
# 855    ['149人付款']    浙江 杭州
# 863    ['632人付款']       上海
# 890    ['873人付款']    广东 广州
# 894    ['332人付款']    江苏 南京
# 905     ['38人付款']    浙江 嘉兴
# 906     ['32人付款']    浙江 嘉兴
# 932    ['227人付款']    广东 深圳
# 961    ['112人付款']    浙江 嘉兴
# 962     ['18人付款']    浙江 嘉兴
# 1020    ['18人付款']    浙江 嘉兴
# 1021    ['75人付款']    浙江 嘉兴
# 1076    ['75人付款']    浙江 嘉兴
# 1077    ['30人付款']    浙江 嘉兴
# 1102   ['125人付款']       重庆
# 1132    ['65人付款']    浙江 嘉兴
# 1133   ['195人付款']    浙江 嘉兴
# 1188     ['4人付款']    浙江 嘉兴
# 1189    ['23人付款']    浙江 嘉兴
# 1247     ['4人付款']    浙江 嘉兴
# 1248    ['23人付款']    浙江 嘉兴
# 1259    ['36人付款']       上海
# 1290     ['7人付款']    浙江 嘉兴
# 1291   ['195人付款']    浙江 嘉兴
# ...           ...      ...
# 3957    ['37人付款']    浙江 杭州
# 3960    ['43人付款']    福建 泉州
# 3971   ['383人付款']    江苏 南京
# 3975    ['43人付款']    福建 泉州
# 3981    ['57人付款']    浙江 嘉兴
# 3982    ['12人付款']    浙江 嘉兴
# 3989    ['37人付款']    浙江 杭州
# 4036     ['5人付款']    浙江 嘉兴
# 4037     ['9人付款']    浙江 嘉兴
# 4053   ['119人付款']    广东 深圳
# 4087    ['17人付款']    浙江 嘉兴
# 4088    ['61人付款']    浙江 嘉兴
# 4116    ['23人付款']    福建 泉州
# 4121   ['203人付款']    广东 深圳
# 4129   ['536人付款']    福建 福州
# 4140    ['16人付款']    浙江 嘉兴
# 4141    ['17人付款']    浙江 嘉兴
# 4148   ['568人付款']    福建 福州
# 4152   ['202人付款']    江苏 南京
# 4195     ['9人付款']    浙江 嘉兴
# 4196     ['8人付款']    浙江 嘉兴
# 4248    ['30人付款']    浙江 嘉兴
# 4249    ['11人付款']    浙江 嘉兴
# 4262   ['119人付款']    江苏 南京
# 4299    ['18人付款']    浙江 嘉兴
# 4300    ['30人付款']    浙江 嘉兴
# 4326   ['452人付款']    广东 广州
# 4347    ['87人付款']    江苏 南京
# 4354    ['30人付款']    浙江 嘉兴
# 4355    ['18人付款']    浙江 嘉兴
#
# [271 rows x 5 columns]

# %%
# 去除重复值
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3855 entries, 0 to 4403
# Data columns (total 5 columns):
# goods_name      3855 non-null object
# shop_name       3855 non-null object
# price           3855 non-null float64
# purchase_num    3855 non-null object
# location        3855 non-null object
# dtypes: float64(1), object(4)
# memory usage: 180.7+ KB

# %%
# 删除购买人数为空的记录
df = df[df['purchase_num'].str.contains('人付款')]
df.shape
# Out:
# (3854, 5)

# %%
# 购买人数
df['purchase_num'] = df['purchase_num'].str.extract('(\d+)').astype('float')
# 销售额
df['sales_volume'] = df['price'] * df['purchase_num']
df.head(2)
# Out:
#                              goods_name         shop_name  price  \
# 0                  永生花礼盒告白玫瑰兔 送女朋友爱人生日礼      joyflower旗舰店  359.0
# 1  THEBEAST/野兽派音乐盒水晶球玫瑰永生花 结婚生日520礼物送女友  thebeast野兽派官方旗舰店  520.0
#
#    purchase_num location  sales_volume
# 0          38.0       北京       13642.0
# 1        1175.0       上海      611000.0

# %%
# 省份处理
df['province_name'] = df.location.str[:2]
df.head(2)
# Out:
#                              goods_name         shop_name  price  \
# 0                  永生花礼盒告白玫瑰兔 送女朋友爱人生日礼      joyflower旗舰店  359.0
# 1  THEBEAST/野兽派音乐盒水晶球玫瑰永生花 结婚生日520礼物送女友  thebeast野兽派官方旗舰店  520.0
#
#    purchase_num location  sales_volume province_name
# 0          38.0       北京       13642.0            北京
# 1        1175.0       上海      611000.0            上海

# %%
txt = df.goods_name.str.cat(sep='。') 

# 添加词典
word_list = ['永生花', '音乐盒', '水晶球', '玫瑰永生花', '玻璃罩礼盒', '玫瑰兔', '手镯', '手链', '首饰']
    
for i in word_list:
    jieba.add_word(i)  
  
# 停用词
stop_words = []
with open(r'C:\Users\wzd\Desktop\CDA\CDA_Learning\Python\Python项目实作\天猫\stop_words.txt', 'r', encoding='utf-8') as f:
    lines = f.readlines()
    for line in lines:
        stop_words.append(line.strip())

stop_words.extend([' ', '925', '2020', '18k', '5.20',
                   '925', '999', '18K', '18k', '740', 
                   '888', '2020', '1314', '100ml'])

word_num = jieba.lcut(txt) 

# 去停用词
word_num_selected = []

for i in word_num:
    if i not in stop_words and len(i)>2:
        word_num_selected.append(i)

# %%
# 计数
df_num = pd.Series(Counter(word_num_selected))
df_num = df_num.sort_values(ascending=False) 
num_top10 = df_num[:10] 
num_top10
# Out:
# 520     3639
# 情人节     1903
# 生日礼物    1216
# 永生花      593
# 女朋友      375
# 玫瑰花      340
# 施华洛      221
# 男朋友      204
# 玻璃罩      199
# 母亲节      179
# dtype: int64

# %%
data = [
    {"value": 593, "name": "永生花"},
    {"value": 340, "name": "玫瑰花"},
    {"value": 221, "name": "施华洛"},
    {"value": 114, "name": "巧克力"},
    {"value": 66, "name": "银项链"},
    {"value": 65, "name": "四叶草"},
    {"value": 65, "name": "音乐盒"},
    {"value": 65, "name": "潘多拉"},
    {"value": 59, "name": "满天星"},
    {"value": 49, "name": "康乃馨"}
]

# %%
tree = TreeMap(init_opts=opts.InitOpts(width="1280px", height="720px"))
tree.add(series_name='', data=data, label_opts=opts.LabelOpts(position='inside'))
tree.set_global_opts(title_opts=opts.TitleOpts(title='520大家都买什么礼物top10'), 
                     legend_opts=opts.LegendOpts(is_show=False))
tree.render()
# Out:
# 'C:\\Users\\wzd\\Desktop\\CDA\\CDA_Learning\\Python\\Python项目实作\\520\\code\\render.html'

# %%
# 绘制柱形图
bar0 = Bar(init_opts=opts.InitOpts(width='1350px', height='750px')) 
bar0.add_xaxis(num_top10.index.tolist()) 
bar0.add_yaxis('', num_top10.values.tolist()) 
bar0.set_global_opts(title_opts=opts.TitleOpts(title='520大家都买什么礼物top10'),
                     xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
                     visualmap_opts=opts.VisualMapOpts(max_=593)) 
bar0.render()
# Out:
# 'C:\\Users\\wzd\\Desktop\\CDA\\CDA_Learning\\Python\\Python项目实作\\520\\code\\render.html'

# %% [markdown]
# ## 数据可视化

# %% [markdown]
# ### 店铺销量排名top10 - 柱形图

# %%
# 计算top10店铺
shop_top10 = df.groupby('shop_name')['purchase_num'].sum().sort_values(ascending=False).head(10)

# 绘制柱形图
bar1 = Bar(init_opts=opts.InitOpts(width='1350px', height='750px')) 
bar1.add_xaxis(shop_top10.index.tolist())
bar1.add_yaxis('', shop_top10.values.tolist()) 
bar1.set_global_opts(title_opts=opts.TitleOpts(title='520礼物商品销量Top10店铺'),
                     xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-15)),
                     visualmap_opts=opts.VisualMapOpts(max_=shop_top10.values.max())) 
bar1.render()
# Out:
# 'C:\\Users\\wzd\\Desktop\\CDA\\CDA_Learning\\Python\\Python项目实作\\520\\code\\render.html'

# %% [markdown]
# ### 全国各省份销量排名Top10 - 柱形图

# %%
# 计算销量top10
province_top10 = df.groupby('province_name')['purchase_num'].sum().sort_values(ascending=False).head(10)

# 条形图
bar2 = Bar(init_opts=opts.InitOpts(width='1350px', height='750px')) 
bar2.add_xaxis(province_top10.index.tolist())
bar2.add_yaxis('', province_top10.values.tolist()) 
bar2.set_global_opts(title_opts=opts.TitleOpts(title='520礼物商品销量省份排名Top10'),
                     visualmap_opts=opts.VisualMapOpts(max_=province_top10.values.max())) 
bar2.render()
# Out:
# 'C:\\Users\\wzd\\Desktop\\CDA\\CDA_Learning\\Python\\Python项目实作\\520\\code\\render.html'

# %% [markdown]
# ### 全国省份销量地区分布-地图

# %%
# 计算销量
province_num = df.groupby('province_name')['purchase_num'].sum().sort_values(ascending=False) 

# 绘制地图
map1 = Map(init_opts=opts.InitOpts(width='1350px', height='750px'))
map1.add("", [list(z) for z in zip(province_num.index.tolist(), province_num.values.tolist())],
         maptype='china'
        ) 
map1.set_global_opts(title_opts=opts.TitleOpts(title='520礼物国内各省份销量分布'),
                     visualmap_opts=opts.VisualMapOpts(max_=province_num.quantile(0.9)),
                    )
map1.render()
# Out:
# 'C:\\Users\\wzd\\Desktop\\CDA\\CDA_Learning\\Python\\Python项目实作\\520\\code\\render.html'

# %% [markdown]
# ### 不同价格区间的商品数量

# %%
def tranform_price(x):
    if x <= 50:
        return '0~50'
    elif x <= 100:
        return '50~100'
    elif x <= 150:
        return '100~150'
    elif x <= 200:
        return '150~200'
    elif x <= 250:
        return '200~250'
    elif x <= 300:
        return '250~300'
    elif x <= 500:
        return '300~500'
    elif x <= 1000:
        return '500~1000'
    elif x <= 2000:
        return '1000~2000'
    elif x <= 5000:
        return '2000~5000'
    else:
        return '5000~10000'
    
df['price_cut'] = df.price.apply(lambda x: tranform_price(x)) 
price_num = df.price_cut.value_counts()
price_num
# Out:
# 150~200       620
# 50~100        594
# 100~150       565
# 300~500       399
# 0~50          395
# 500~1000      394
# 250~300       302
# 1000~2000     273
# 200~250       212
# 2000~5000      91
# 5000~10000      9
# Name: price_cut, dtype: int64

# %%
x_data = ['0~50', '50~100', '100~150', '150~200', '200~250', '250~300', 
          '300~500', '500~1000', '1000~2000', '2000~5000', '5000~10000']
y_data = [395, 594, 565, 620, 212, 302, 399, 394, 273, 91, 9]

# %%
bar3 = Bar(init_opts=opts.InitOpts(width='1350px', height='750px')) 
bar3.add_xaxis(x_data)
bar3.add_yaxis('', y_data) 
bar3.set_global_opts(title_opts=opts.TitleOpts(title='520不同价格区间的商品数量'),
                     visualmap_opts=opts.VisualMapOpts(max_=800)) 
bar3.render()
# Out:
# 'C:\\Users\\wzd\\Desktop\\CDA\\CDA_Learning\\Python\\Python项目实作\\520\\code\\render.html'

# %%
price_cut_num = df.groupby('price_cut')['purchase_num'].sum() 
data_pair = [list(z) for z in zip(price_cut_num.index, price_cut_num.values)]

# %%
# 饼图
pie1 = Pie(init_opts=opts.InitOpts(width='1350px', height='750px'))
# 内置富文本
pie1.add( 
        series_name="",
        radius=["35%", "55%"],
        data_pair=data_pair,
        label_opts=opts.LabelOpts(
            position="outside",
            formatter="{b|{b}: }{c}  {per|{d}%}  ",
            background_color="#eee",
            border_color="#aaa",
            border_width=1,
            border_radius=4,
            rich={
                "a": {"color": "#999", "lineHeight": 22, "align": "center"},
                "abg": {
                    "backgroundColor": "#e3e3e3",
                    "width": "100%",
                    "align": "right",
                    "height": 22,
                    "borderRadius": [4, 4, 0, 0],
                },
                "hr": {
                    "borderColor": "#aaa",
                    "width": "100%",
                    "borderWidth": 0.5,
                    "height": 0,
                },
                "b": {"fontSize": 16, "lineHeight": 33},
                "per": {
                    "color": "#eee",
                    "backgroundColor": "#334455",
                    "padding": [2, 4],
                    "borderRadius": 2,
                },
            },
        ),
)
pie1.set_global_opts(legend_opts=opts.LegendOpts(pos_left="left", pos_top='30%', orient="vertical"), 
                     title_opts=opts.TitleOpts(title='520礼物不同价格区间销量占比'))
pie1.set_series_opts(
    tooltip_opts=opts.TooltipOpts(trigger="item", formatter="{a} <br/>{b}: {c} ({d}%)")
    )
pie1.render()
# Out:
# 'C:\\Users\\wzd\\Desktop\\CDA\\CDA_Learning\\Python\\Python项目实作\\520\\code\\render.html'

# %%
# 词云图
word1 = WordCloud(init_opts=opts.InitOpts(width='1350px', height='750px'))
word1.add("", [*zip(df_num[:100].index.astype('str'), df_num[:100].values.astype('str'))],
          word_size_range=[20, 200],
          shape=SymbolType.DIAMOND)
word1.set_global_opts(title_opts=opts.TitleOpts('520礼物商品标题词云图'))
word1.render()
# Out:
# 'C:\\Users\\wzd\\Desktop\\CDA\\CDA_Learning\\Python\\Python项目实作\\520\\code\\render.html'

# %%
page = Page()
page.add(tree, bar1, bar2, map1, bar3, pie1, word1)
page.render('520天猫数据分析.html')
# Out:
# 'C:\\Users\\wzd\\Desktop\\CDA\\CDA_Learning\\Python\\Python项目实作\\520\\code\\520天猫数据分析.html'
